# %% [markdown]
# # Total Dataset mining

# %%
import pandas as pd 
import numpy as np
from datetime import date,datetime
import csv
import re
from multiprocessing import Pool
from functools import partial
from sklearn import preprocessing
from IPython.core import display as ICD
import matplotlib.pyplot as plt
import itertools
import os

# %%
# TODO add doc 
def dataset_property_split(df,frequency,properties,min_support,groupby_property="CUST_ID",itemset_property="ARTICLE_ID",temp_folder="lcm_temp",indexation_folder="index"):
    """Split dataset """
    for period,i in df.groupby(pd.Grouper(freq = frequency)):
        for values,ii in i.groupby(properties):
            if len(properties)>1:
                values = '_'.join(str(z) for z in values)
            
            split_name = f"{temp_folder}/{period}_{values}#{min_support}"
            index_file_name = f"{indexation_folder}/{period}_{values}#{min_support}"

            ii = ii.groupby(groupby_property)[itemset_property].apply(lambda x: " ".join(str(z) for z in x))
            
            ii.to_csv(split_name,index=None,header=False)
            pd.DataFrame(ii.index).to_csv(index_file_name,header=False,index=None)
            yield str(split_name)
        
def reformat_output(unformated_result,split_name,index_folder="index"):
    """
    Reformat default output of lcm  to a dataframe with structure : min_support,itemsets,users
    """
    output = pd.DataFrame([unformated_result[0::2],unformated_result[1::2]]).T
    output = pd.concat([output.drop(0,axis=1),output[0].str.split('\(([0-9]+)\)',expand=True).drop(0,axis=1)],axis=1)
    split_name= split_name.split("/")[1] #remove temp folder from name

    output["period"] = split_name.split("_")[0]
    output["property_values"] = "_".join(split_name.split("_")[1:]).split("#")[0]
    output.columns = ["CUST_ID","support","itemset","period","property_values"]

    indexes = pd.read_csv(f'{index_folder}/{split_name}',header=None)[0].to_dict()
    output["CUST_ID"]= output["CUST_ID"].map(lambda x : [indexes[int(i)] for i in x.split()])
    
    return output


# TODO doc for support
def run_lcm(split_name,itemsets_size,support,output_file):
    """Runs LCM (Single Thread)  and return the  result formated with format_output
    
    Example for parameters : input_file='1999',support=6, itemsets_size=[5,100]
    Executed command :  $ ./lcm C_QI -l 5 -u 100 1999 6 -
    
    Preconfigured parameters:  
     C: enumerate closed frequent itemsets
     M: enumerate maximal frequent itemsets 
     Q: output the frequency on the head of each itemset found,
     I: output ID's of transactions including each itemset; ID of a transaction is given by the number of line in which the transaction is written. The ID starts from 0.
     _: no output to standard output (including messages w.r.t. input data)
     -l,-u [num]: enumerate itemsets with size at least/most [num]  
   
    Output:
        Replace file having name input_file with the result : support,itemset,users
        if no itemset found the input_file is deleted and output is empty string ""
    """
    support = int(support)
    result = !./lcm C_QI -l {itemsets_size[0]} -# {itemsets_size[1]}  {split_name} {support} -
    os.remove(split_name)
    if "there is no frequent item" in str(result) or result == []:
        print("No itemset",split_name)
        return 
    print("Found ",len(result)/2," in",split_name )
    reformat_output(result,split_name).to_csv(output_file,header=False,index=None,mode="a")
    return split_name


def multithread_lcm(input_file,frequency,support,itemsets_size,properties,output_file):
    f = partial(run_lcm,itemsets_size=itemsets_size,support=support, output_file=output_file)
    p = Pool(8)
    res  = p.imap_unordered(f,dataset_property_split(input_file,frequency,properties,support))
    p.close()
    p.join()
    return res
                                              
def linear_closed_itemset_miner(df,frequency,min_support,itemsets_size,properties):
    output_file = f'lcm_results/{frequency}-{min_support}-[{itemsets_size[0]}-{itemsets_size[1]}]-[{",".join(str(i) for i in properties)}]-lcm.out'
    a = multithread_lcm(df,frequency,min_support,itemsets_size,properties,output_file)
    total  = len(a._items)
    print(a,total)
    a = [i for i in a if i is not None]
    print(f"---| {output_file} Done")
    print(f'---| #split total: {total}')
    print(f'---| #split having groups: {len(a)}')
    print(f'---| Average: {len(a)/total}')
    print(" ")
    
    
def age_class(age):
    """User age to range classes """
    age = np.int(age)
    if age<=25:
        return 0
    if age<=45:
        return 1
    return 2

# %%
def prepare_data(file_name,folder_name="datasets/Total/data/"):
    df = pd.read_csv(f"datasets/Total/data/{file_name}",sep=";")
    df_users = pd.read_csv("datasets/Total/users.csv",sep=";")
    df = df.merge(df_users,on="CUST_ID")
    df.index = pd.to_datetime(df.TRANSACTION_DATE).dt.to_period("D")
    return df

# %%
a = !ls datasets/Total/data
df = pd.DataFrame()
for i in a:
    df = pd.concat([pd.read_csv(f"datasets/Total/data/{i}",sep=";"),df])
df_users = pd.read_csv("datasets/Total/users.csv",sep=";")
df = df.merge(df_users,on="CUST_ID")
df.index = pd.to_datetime(df.TRANSACTION_DATE).dt.to_period("D")
df["STATION_DEPARTEMENT_ID"] = df.STATION_ID.apply(lambda x : x[3:5])
df = df[df.STATION_DEPARTEMENT_ID==df.DEPARTEMENT]
stations = pd.read_csv("datasets/Total/STATION_TYPE.csv",sep=";")
df = df.merge(stations,on="STATION_ID").dropna()
df.index = pd.to_datetime(df.TRANSACTION_DATE).dt.to_period("D")
df.head()
# Out:
#                                      TRANS_ID     TRANSACTION_DATE STATION_ID  \
# TRANSACTION_DATE
# 2019-10-25        NF0785449300987191025085416  2019-10-25 09:00:22   NF078544
# 2019-09-23        NF0785449300953190923065643  2019-09-23 06:58:06   NF078544
# 2019-08-08        NF0785449300905190808194211  2019-08-08 19:43:48   NF078544
# 2019-08-08        NF0785449300905190808194211  2019-08-08 19:44:54   NF078544
# 2019-09-23        NF0785449300953190923065643  2019-09-23 06:58:06   NF078544
#
#                   CUST_ID     ARTICLE_ID TTC_PRICE SEX    AGE DEPARTEMENT  \
# TRANSACTION_DATE
# 2019-10-25        1045120       12520268         2   M  50-65          78
# 2019-09-23        1045120       12520268         2   M  50-65          78
# 2019-08-08        1045120       12520268         2   M  50-65          78
# 2019-08-08        1045120       12520268         2   M  50-65          78
# 2019-09-23        1045120  3425909003391      0,01   M  50-65          78
#
#                  STATION_DEPARTEMENT_ID STATION_MGT_TYPE
# TRANSACTION_DATE
# 2019-10-25                           78             COCO
# 2019-09-23                           78             COCO
# 2019-08-08                           78             COCO
# 2019-08-08                           78             COCO
# 2019-09-23                           78             COCO

# %%
frequencies =["M","2M","3M"]
properties = [["STATION_MGT_TYPE"],["STATION_MGT_TYPE","DEPARTEMENT"]]
from itertools import product

# %%
for frequency,prop in product(frequencies,properties):
    linear_closed_itemset_miner(df,frequency,5,[2,"5000"],prop)
# Out:
# No itemset lcm_temp/2017-02_CODO#5
# No itemset lcm_temp/2017-02_COCO#5
# No itemset lcm_temp/2017-02_DODO#5
# No itemset lcm_temp/2017-03_DODO#5
# No itemset lcm_temp/2017-03_CODO#5
# Found  6.0  in lcm_temp/2017-03_COCO#5
# Found  4.0  in lcm_temp/2017-04_COCO#5
# No itemset lcm_temp/2017-04_DODO#5
# No itemset lcm_temp/2017-05_DODO#5
# No itemset lcm_temp/2017-04_CODO#5
# No itemset lcm_temp/2017-06_DODO#5
# No itemset lcm_temp/2017-05_CODO#5
# Found  3.0  in lcm_temp/2017-05_COCO#5
# No itemset lcm_temp/2017-06_CODO#5
# Found  7.0  in lcm_temp/2017-06_COCO#5
# No itemset lcm_temp/2017-07_DODO#5
# Found  27.0  in lcm_temp/2017-07_COCO#5
# No itemset lcm_temp/2017-07_CODO#5
# No itemset lcm_temp/2017-09_DODO#5
# Found  7.0  in lcm_temp/2017-08_COCO#5
# No itemset lcm_temp/2017-08_CODO#5
# No itemset lcm_temp/2017-08_DODO#5
# No itemset lcm_temp/2017-10_DODO#5
# No itemset lcm_temp/2017-09_CODO#5
# No itemset lcm_temp/2017-11_DODO#5
# No itemset lcm_temp/2017-10_CODO#5
# Found  5.0  in lcm_temp/2017-10_COCO#5
# No itemset lcm_temp/2018-01_DODO#5
# No itemset lcm_temp/2017-11_CODO#5
# Found  2.0  in lcm_temp/2017-11_COCO#5
# No itemset lcm_temp/2018-01_CODO#5
# No itemset lcm_temp/2018-03_DODO#5
# Found  3.0  in lcm_temp/2017-12_COCO#5
# No itemset lcm_temp/2018-02_DODO#5
# No itemset lcm_temp/2018-02_CODO#5
# Found  1.0  in lcm_temp/2018-01_COCO#5
# Found  1.0  in lcm_temp/2018-02_COCO#5
# No itemset lcm_temp/2018-03_CODO#5
# Found  3.0  in lcm_temp/2018-03_COCO#5
# No itemset lcm_temp/2018-04_DODO#5
# No itemset lcm_temp/2018-04_CODO#5
# No itemset lcm_temp/2018-05_DODO#5
# No itemset lcm_temp/2018-05_CODO#5
# Found  12.0  in lcm_temp/2018-05_COCO#5
# No itemset lcm_temp/2018-06_DODO#5
# No itemset lcm_temp/2018-06_CODO#5
# Found  6.0  in lcm_temp/2018-06_COCO#5
# No itemset lcm_temp/2018-07_CODO#5
# No itemset lcm_temp/2018-07_DODO#5
# Found  8.0  in lcm_temp/2018-07_COCO#5
# No itemset lcm_temp/2018-08_DODO#5
# No itemset lcm_temp/2018-08_CODO#5
# Found  11.0  in lcm_temp/2018-08_COCO#5
# No itemset lcm_temp/2018-09_CODO#5
# No itemset lcm_temp/2018-09_DODO#5
# Found  7.0  in lcm_temp/2018-09_COCO#5
# No itemset lcm_temp/2018-10_CODO#5
# No itemset lcm_temp/2018-12_DODO#5
# Found  13.0  in lcm_temp/2018-10_COCO#5
# No itemset lcm_temp/2018-10_DODO#5
# No itemset lcm_temp/2018-11_DODO#5
# No itemset lcm_temp/2018-11_CODO#5
# Found  7.0  in lcm_temp/2018-11_COCO#5
# No itemset lcm_temp/2018-12_CODO#5
# Found  6.0  in lcm_temp/2018-12_COCO#5
# Found  1.0  in lcm_temp/2019-01_CODO#5
# No itemset lcm_temp/2019-01_DODO#5
# Found  6.0  in lcm_temp/2019-01_COCO#5
# No itemset lcm_temp/2019-02_CODO#5
# No itemset lcm_temp/2019-02_DODO#5
# Found  5.0  in lcm_temp/2019-02_COCO#5
# No itemset lcm_temp/2019-03_CODO#5
# No itemset lcm_temp/2019-03_DODO#5
# Found  4.0  in lcm_temp/2019-03_COCO#5
# No itemset lcm_temp/2019-04_CODO#5
# No itemset lcm_temp/2019-04_DODO#5
# Found  5.0  in lcm_temp/2019-04_COCO#5
# No itemset lcm_temp/2019-05_CODO#5
# No itemset lcm_temp/2019-05_DODO#5
# No itemset lcm_temp/2019-06_DODO#5
# Found  3.0  in lcm_temp/2019-05_COCO#5
# No itemset lcm_temp/2019-06_CODO#5
# Found  4.0  in lcm_temp/2019-06_COCO#5
# No itemset lcm_temp/2019-07_CODO#5
# Found  5.0  in lcm_temp/2019-07_COCO#5
# No itemset lcm_temp/2019-07_DODO#5
# No itemset lcm_temp/2019-08_DODO#5
# No itemset lcm_temp/2019-08_CODO#5
# Found  3.0  in lcm_temp/2019-08_COCO#5
# No itemset lcm_temp/2019-09_DODO#5
# Found  2.0  in lcm_temp/2019-09_COCO#5
# No itemset lcm_temp/2019-09_CODO#5
# No itemset lcm_temp/2019-10_CODO#5
# No itemset lcm_temp/2019-10_DODO#5
# Found  3.0  in lcm_temp/2019-10_COCO#5
# <multiprocessing.pool.IMapUnorderedIterator object at 0x7fdeeff97d30> 99
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-5-beb2528a7c6a>", line 56, in run_lcm
#     result = get_ipython().getoutput('./lcm C_QI -l {itemsets_size[0]} -# {itemsets_size[1]}  {split_name} {support} -')
#   File "/home/abdelwahab/.virtualenvs/3env/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2529, in getoutput
#     out = getoutput(self.var_expand(cmd, depth=depth+1))
#   File "/home/abdelwahab/.virtualenvs/3env/local/lib/python3.7/site-packages/IPython/utils/_process_common.py", line 130, in getoutput
#     out = process_handler(cmd, lambda p: p.communicate()[0], subprocess.STDOUT)
#   File "/home/abdelwahab/.virtualenvs/3env/local/lib/python3.7/site-packages/IPython/utils/_process_common.py", line 84, in process_handler
#     close_fds=close_fds)
#   File "/usr/lib/python3.7/subprocess.py", line 775, in __init__
#     restore_signals, start_new_session)
#   File "/usr/lib/python3.7/subprocess.py", line 1453, in _execute_child
#     restore_signals, start_new_session, preexec_fn)
# OSError: [Errno 12] Cannot allocate memory
# """
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-26-b0c6e9dc92da> in <module>
#       1 for frequency,prop in product(frequencies,properties):
# ----> 2     linear_closed_itemset_miner(df,frequency,5,[2,"5000"],prop)
#
# <ipython-input-5-beb2528a7c6a> in linear_closed_itemset_miner(df, frequency, min_support, itemsets_size, properties)
#      77     total  = len(a._items)
#      78     print(a,total)
# ---> 79     a = [i for i in a if i is not None]
#      80     print(f"---| {output_file} Done")
#      81     print(f'---| #split total: {total}')
#
# <ipython-input-5-beb2528a7c6a> in <listcomp>(.0)
#      77     total  = len(a._items)
#      78     print(a,total)
# ---> 79     a = [i for i in a if i is not None]
#      80     print(f"---| {output_file} Done")
#      81     print(f'---| #split total: {total}')
#
# /usr/lib/python3.7/multiprocessing/pool.py in next(self, timeout)
#     746         if success:
#     747             return value
# --> 748         raise value
#     749
#     750     __next__ = next                    # XXX
#
# OSError: [Errno 12] Cannot allocate memory

# %%
# Out:
# ['APRIL_JUNE2018.csv',
#  'APRIL_JUNE2019.csv',
#  'AUG_DEC2017.csv',
#  'JAN_JULY2017.csv',
#  'JAN_MARCH2019.csv',
#  'JAN_MARS2018.csv',
#  'JULY_OCT2019.csv',
#  'JULY_SEPT2018.csv',
#  'OCT_DEC2018.csv']

# %% [markdown]
# # Draft

# %% [markdown]
# # CSV files content

# %%
users_df = pd.read_csv("datasets/Total/users.csv",sep=";")

# %%
users_df.head()
# Out:
#    CUST_ID SEX  AGE DEPARTEMENT
# 0  1058702   M  <35          31
# 1  1006799   M  <35          77
# 2  1203632   M  <35          31
# 3   619087   M  <35          39
# 4  1217481   F  <35          37

# %%
stations = pd.read_csv("datasets/Total/STATION_TYPE.csv",sep=";")

# %%
stations.head()
# Out:
#   STATION_ID STATION_MGT_TYPE
# 0   NF078198             CODO
# 1   NF079079             DODO
# 2   NF078243             COCO
# 3   NF058570             CODO
# 4   NF050214             CODO

# %%
df = pd.read_csv("datasets/Total/data/JAN_MARS2018.csv",sep=";")

# %%
df.head()
# Out:
#                       TRANS_ID     TRANSACTION_DATE STATION_ID  CUST_ID  \
# 0  NF0781029900123180212082507  2018-02-12 08:26:04   NF078102   487708
# 1  NF0589111285987180117195711  2018-01-17 19:57:11   NF058911   826063
# 2  NF0781441356712180206165242  2018-02-06 16:52:42   NF078144   519500
# 3  NF0780161338229180117123916  2018-01-17 12:39:16   NF078016   800779
# 4  NF0620881123266180310085619  2018-03-10 08:56:19   NF062088   942788
#
#       ARTICLE_ID TTC_PRICE
# 0        7445935       1,7
# 1  3760122966116      2,75
# 2  3017626904206       2,7
# 3  3551720026384       2,8
# 4  3425909000130        10

# %%
regions = pd.read_csv("datasets/Total/region_par_departement.csv",engine='python')

# %%
df.head()
# Out:
#                                      TRANS_ID     TRANSACTION_DATE STATION_ID  \
# TRANSACTION_DATE
# 2018-11-20        NF0780021166918181120202421  2018-11-20 20:24:21   NF078002
# 2017-11-04        NF0785761393795171104112042  2017-11-04 11:21:26   NF078576
# 2018-01-30        NF0075021238954180130172918  2018-01-30 17:29:18   NF007502
# 2018-02-05        NF0075021546655180205163614  2018-02-05 16:36:14   NF007502
# 2018-01-30        NF0075021238954180130172918  2018-01-30 17:29:18   NF007502
#
#                   CUST_ID     ARTICLE_ID TTC_PRICE SEX    AGE DEPARTEMENT  \
# TRANSACTION_DATE
# 2018-11-20         350541  3217770314146         3   M  50-65          78
# 2017-11-04         350541       40111216       1,5   M  50-65          78
# 2018-01-30         931963  5053990107384      1,95   M    <35          07
# 2018-02-05         931963  5053990107339      1,95   M    <35          07
# 2018-01-30         931963  5053990107384      1,95   M    <35          07
#
#                  STATION_DEPARTEMENT_ID
# TRANSACTION_DATE
# 2018-11-20                           78
# 2017-11-04                           78
# 2018-01-30                           07
# 2018-02-05                           07
# 2018-01-30                           07

# %%
df.merge(stations,on="STATION_ID").dropna()
# Out:
#                            TRANS_ID     TRANSACTION_DATE STATION_ID  CUST_ID  \
# 0       NF0780021166918181120202421  2018-11-20 20:24:21   NF078002   350541
# 1       NF0780021164260181112162620  2018-11-12 16:26:20   NF078002   220201
# 2       NF0780021164260181112162620  2018-11-12 16:26:20   NF078002   220201
# 3       NF0780021172693181207155540  2018-12-07 15:55:40   NF078002   220201
# 4       NF0780021172693181207155540  2018-12-07 15:55:40   NF078002   220201
# ...                             ...                  ...        ...      ...
# 238622  NF0741751168592190629093710  2019-06-29 09:37:10   NF074175   217273
# 238624  NF0594969700690190614132821  2019-06-14 13:30:44   NF059496  1211596
# 238625  NF0801881193100190603110518  2019-06-03 11:05:18   NF080188   700783
# 238626  NF0801881193100190603110518  2019-06-03 11:05:18   NF080188   700783
# 238627  NF0801881193100190603110518  2019-06-03 11:05:18   NF080188   700783
#
#            ARTICLE_ID TTC_PRICE SEX    AGE DEPARTEMENT STATION_DEPARTEMENT_ID  \
# 0       3217770314146         3   M  50-65          78                     78
# 1       3425909000482         7   F  50-65          78                     78
# 2       3217770314146         3   F  50-65          78                     78
# 3       8727900384505      29,9   F  50-65          78                     78
# 4       3425909000482         7   F  50-65          78                     78
# ...               ...       ...  ..    ...         ...                    ...
# 238622  3425909001236        12   M  50-65          74                     74
# 238624  3217770310841       5,9   M    <35          59                     59
# 238625  3701239300011      18,5   M  35-49          80                     80
# 238626  3701239300011      18,5   M  35-49          80                     80
# 238627  3701239300011      18,5   M  35-49          80                     80
#
#        STATION_MGT_TYPE
# 0                  CODO
# 1                  CODO
# 2                  CODO
# 3                  CODO
# 4                  CODO
# ...                 ...
# 238622             DODO
# 238624             CODO
# 238625             CODO
# 238626             CODO
# 238627             CODO
#
# [238435 rows x 11 columns]

# %% [markdown]
# stations_xls = pd.ExcelFile("datasets/Total/Liste des stations 20190930.xlsm")

# %%
pd.read_excel(stations_xls,"Stations actives")
# Out:
#             Marque   Canal de Vente Code Implant  \
# 0     ELF MARQUAGE             CODO     NF078072
# 1            TOTAL   COCO Autoroute     NF006369
# 2            TOTAL   COCO Autoroute     NF006467
# 3            TOTAL   COCO Autoroute     NF007052
# 4            TOTAL   COCO Autoroute     NF007451
# ...            ...              ...          ...
# 2104  TOTAL ACCESS  Commissionnaire     NF080212
# 2105  TOTAL ACCESS  Commissionnaire     NF080213
# 2106  TOTAL ACCESS  Commissionnaire     NF080238
# 2107  TOTAL ACCESS  Commissionnaire     NF081810
# 2108  TOTAL ACCESS  Commissionnaire     NF083217
#
#                        Nom de Site  Code Client  \
# 0             RELAIS DES  AGNETTES       522068
# 1                   REL.LES LISSES       327430
# 2                      REL.SOLAIZE       214335
# 3       REL.LANCON DE PROVENCE EST       223709
# 4     REL.LES TERRES DE GRAVES SUD       222074
# ...                            ...          ...
# 2104  CATALOGNE CARBURANTS NORD VL       893043
# 2105  CATALOGNE CARBURANTS NORD PL       893057
# 2106            SAS GARAGE FLOQUET       906090
# 2107               RELAIS  GEBHARD       226924
# 2108            EURL STATION COLAS       492956
#
#                                    Nom de Client     SIREN    NIC  \
# 0            SARL JSD CARBUR/RELAIS DES AGNETTES  509880506    19
# 1                   SAS ARGEDIS / REL.LES LISSES  306916099  1665
# 2                      SAS ARGEDIS / REL.SOLAIZE  306916099  1137
# 3       SAS ARGEDIS / REL.LANCON DE PROVENCE EST  306916099  1590
# 4     SAS ARGEDIS / REL.LES TERRES DE GRAVES SUD  306916099  1624
# ...                                          ...        ...   ...
# 2104           SARL CATALOGNE CARBURANTS NORD VL  844112052    15
# 2105           SARL CATALOGNE CARBURANTS NORD PL  844112052    15
# 2106                          SAS GARAGE FLOQUET  301621512    21
# 2107          SAS STE NOUVELLE GEBHARD-PNEU/REL.  403742778    18
# 2108                          EURL STATION COLAS  503625063    14
#
#                 TVA                               Rue  ... GPL en mandat  \
# 0     FR30509880506              113 AV LAURENT  CELY  ...
# 1     FR59306916099          A6  -  AIRE DES   LISSES  ...             X
# 2     FR59306916099              A7 - AIRE DE SOLAIZE  ...             X
# 3     FR59306916099  A7 - AIRE DE LANCON DE   PROVENC  ...             X
# 4     FR59306916099   A62 - AIRE DES TERRES DE GRAVES  ...             X
# ...             ...                               ...  ...           ...
# 2104  FR42844112052         IMPASSE JACQUES DE  NOELL  ...
# 2105  FR42844112052          IMPASSE JACQUES DE NOELL  ...
# 2106  FR48301621512              131 AVENUE D'ORLEANS  ...
# 2107  FR16403742778                  ROUTE DE LIMOGES  ...
# 2108  FR00503625063                 RN 177 - LES BOIS  ...
#
#                                      Adresse Mail  \
# 0                             NF078072@resmail.fr
# 1                 ds.leslisses@station-argedis.fr
# 2                   ds.solaize@station-argedis.fr
# 3       ds.lancondeprovenceest@station-argedis.fr
# 4      ds.lesterresdegravessud@station-argedis.fr
# ...                                           ...
# 2104                       th.prax@groupe-prax.fr
# 2105                       th.prax@groupe-prax.fr
# 2106                       d.chadoutaud@faurie.fr
# 2107  comptabilitegebhard@groupe-chiraultpneus.fr
# 2108                   olivier.colas35@icloud.com
#
#            Nom du Dépôt de Référence  Wash Business Manager Segmentation  \
# 0           0100-GENNEVILLIERS TOTAL     Mme Lucille HOUARD       Access
# 1               0100-RAFF.GRANDPUITS  M. Bengue BAMBA - FNT    Autoroute
# 2                   0100-RAFF FEYZIN     M. Yoann PARTOUCHE    Autoroute
# 3                          0100-DPLM    M. FRANCK CHAUMARAT    Autoroute
# 4                   0100-BASSENS DPA       M. Geraud SOLLIN    Autoroute
# ...                              ...                    ...          ...
# 2104     0100-PORT LA NOUVELLE TOTAL                    NaN       Access
# 2105     0100-PORT LA NOUVELLE TOTAL                    NaN       Access
# 2106       0100-ST JEAN DE BRAYE DPO                    NaN       Access
# 2107  0100-ST PIERRE DES CORPS GPSPC                    NaN       Access
# 2108                 0100-VERN TOTAL                    NaN       Access
#
#                        SDM Correspondant Flux Hors Carburants  \
# 0     M. Romuald CONTASSOT                   Mme Sonia DAZZAN
# 1                      NaN                M. Guillaume SENARD
# 2                      NaN                M. Guillaume SENARD
# 3                      NaN                M. Guillaume SENARD
# 4                      NaN                M. Guillaume SENARD
# ...                    ...                                ...
# 2104                   NaN                   Mme Sonia DAZZAN
# 2105                   NaN                   Mme Sonia DAZZAN
# 2106                   NaN                Mme Lydie DOUILLARD
# 2107                   NaN                   Mme Sonia DAZZAN
# 2108                   NaN                M. Guillaume SENARD
#
#           Chargé d'Affaires GOB10 Sites Full Automate
# 0       Mme Anne TIBERGHIEN   NaN                 NaN
# 1     M. Mickael TRIBALLEAU   NaN                 NaN
# 2         Mr Anthony HUGUET   NaN                 NaN
# 3         Mr Anthony HUGUET   NaN                 NaN
# 4         Mr Anthony HUGUET   NaN                 NaN
# ...                     ...   ...                 ...
# 2104     M. Francis BIZZARI   NaN                   X
# 2105     M. Francis BIZZARI   NaN                   X
# 2106      Mme Audrey DUGAST   NaN                   X
# 2107          M. Hervé GOIX   NaN                 NaN
# 2108          M. Hervé GOIX   NaN                 NaN
#
# [2109 rows x 55 columns]

# %%
stats = df[["ARTICLE_ID","DEPARTEMENT","CUST_ID"]]

# %%
stats[["CUST_ID","DEPARTEMENT"]].drop_duplicates()["DEPARTEMENT"].value_counts().plot.bar(figsize=(15,5))

# %%
stats[:1000].groupby([pd.Grouper(freq = "2M")]+["DEPARTEMENT"])["ARTICLE_ID"].value_counts().to_frame()
# Out:
#                                             ARTICLE_ID
# TRANSACTION_DATE DEPARTEMENT ARTICLE_ID
# 2018-04          06          12520039                1
#                              3175681054158           1
#                              3178530404241           1
#                              3178530409734           1
#                              3242272845256           1
# ...                                                ...
# 2018-06          79          3068320105444           1
#                  88          54492790                1
#                              76222320                1
#                              3103220037218           1
#                              5449000232465           1
#
# [589 rows x 1 columns]

# %%
stats.ARTICLE_ID.value_counts().plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-133-7be820fe9691> in <module>
# ----> 1 ARTICLE_ID.value_counts().plot(kind='bar')
#
# NameError: name 'ARTICLE_ID' is not defined

# %%
pd.read_csv("datasets/Total/data/JAN_MARS2018.csv",sep=";")[["CUST_ID","STATION_ID"]].drop_duplicates()["CUST_ID"].value_counts().to_frame()
# Out:
#          CUST_ID
# 525095        50
# 244081        37
# 1013705       32
# 199517        28
# 572983        26
# ...          ...
# 554871         1
# 490813         1
# 488764         1
# 513923         1
# 1056772        1
#
# [199068 rows x 1 columns]

# %%
df.groupby([pd.Grouper(freq="M")]+["DEPARTEMENT"])["ARTICLE_ID"].value_counts().to_frame().plot()
